# %%
import pandas as pd
import random
import requests
import numpy as np
from citipy import citipy
from config import weather_api_key
import time
from datetime import datetime

# %%
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)

# %%
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the begining of the logging.
print("Beginning Data Retrieval")
print("------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current = city_weather["weather"][0]["description"]



        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | kulhudhuffushi
# Processing Record 3 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 1 | carutapera
# Processing Record 5 of Set 1 | dikson
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 1 | at-bashi
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | sitka
# Processing Record 13 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | pisco
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | leningradskiy
# Processing Record 18 of Set 1 | rocha
# Processing Record 19 of Set 1 | douglas
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | muros
# Processing Record 24 of Set 1 | dryden
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | katobu
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | henties bay
# Processing Record 36 of Set 1 | maceio
# Processing Record 37 of Set 1 | jiwani
# Processing Record 38 of Set 1 | timbio
# City not found. Skipping...
# Processing Record 39 of Set 1 | suruc
# Processing Record 40 of Set 1 | oktyabrskiy
# Processing Record 41 of Set 1 | starokamyshinsk
# Processing Record 42 of Set 1 | sidrolandia
# Processing Record 43 of Set 1 | san patricio
# Processing Record 44 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | balclutha
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 2 | port lincoln
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | punta arenas
# Processing Record 6 of Set 2 | olafsvik
# Processing Record 7 of Set 2 | bonavista
# Processing Record 8 of Set 2 | yulara
# Processing Record 9 of Set 2 | biak
# Processing Record 10 of Set 2 | east london
# Processing Record 11 of Set 2 | maykain
# City not found. Skipping...
# Processing Record 12 of Set 2 | aklavik
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | constitucion
# Processing Record 15 of Set 2 | barra do corda
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | saldanha
# Processing Record 20 of Set 2 | tessalit
# Processing Record 21 of Set 2 | skelleftea
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | pevek
# Processing Record 26 of Set 2 | kruisfontein
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | kavieng
# Processing Record 29 of Set 2 | pangnirtung
# Processing Record 30 of Set 2 | hofn
# Processing Record 31 of Set 2 | gubkinskiy
# Processing Record 32 of Set 2 | romitan
# Processing Record 33 of Set 2 | nunchia
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | jalu
# Processing Record 37 of Set 2 | nanortalik
# Processing Record 38 of Set 2 | mana
# Processing Record 39 of Set 2 | cape town
# Processing Record 40 of Set 2 | gorokhovets
# Processing Record 41 of Set 2 | mar del plata
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | qaanaaq
# Processing Record 44 of Set 2 | rawson
# Processing Record 45 of Set 2 | pakwach
# City not found. Skipping...
# Processing Record 46 of Set 2 | saint-augustin
# Processing Record 47 of Set 2 | khasan
# Processing Record 48 of Set 2 | berdigestyakh
# Processing Record 49 of Set 2 | ancud
# Processing Record 50 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 3 | norman wells
# Processing Record 2 of Set 3 | hella
# Processing Record 3 of Set 3 | vostok
# Processing Record 4 of Set 3 | grindavik
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | austin
# Processing Record 7 of Set 3 | plettenberg bay
# Processing Record 8 of Set 3 | sungairaya
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | bluff
# Processing Record 11 of Set 3 | gat
# Processing Record 12 of Set 3 | hermanus
# Processing Record 13 of Set 3 | brae
# Processing Record 14 of Set 3 | batagay-alyta
# Processing Record 15 of Set 3 | northam
# Processing Record 16 of Set 3 | kapaa
# Processing Record 17 of Set 3 | shuiji
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | kismayo
# Processing Record 20 of Set 3 | itarema
# Processing Record 21 of Set 3 | springbok
# Processing Record 22 of Set 3 | hambantota
# Processing Record 23 of Set 3 | ponta do sol
# Processing Record 24 of Set 3 | khandyga
# Processing Record 25 of Set 3 | borovoy
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | parana
# Processing Record 28 of Set 3 | huarmey
# Processing Record 29 of Set 3 | touros
# Processing Record 30 of Set 3 | koumac
# Processing Record 31 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 3 | victoria point
# Processing Record 33 of Set 3 | haines junction
# Processing Record 34 of Set 3 | inuvik
# Processing Record 35 of Set 3 | nardaran
# Processing Record 36 of Set 3 | hovd
# Processing Record 37 of Set 3 | lasa
# Processing Record 38 of Set 3 | sao jose da coroa grande
# Processing Record 39 of Set 3 | north bend
# Processing Record 40 of Set 3 | avarua
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | kuminskiy
# Processing Record 43 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 3 | bathsheba
# Processing Record 45 of Set 3 | laela
# Processing Record 46 of Set 3 | sao joao da barra
# Processing Record 47 of Set 3 | collie
# Processing Record 48 of Set 3 | laguna
# Processing Record 49 of Set 3 | asau
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | tarpon springs
# Processing Record 2 of Set 4 | padang
# Processing Record 3 of Set 4 | kondinskoye
# Processing Record 4 of Set 4 | athens
# Processing Record 5 of Set 4 | sao filipe
# Processing Record 6 of Set 4 | bud
# Processing Record 7 of Set 4 | prince albert
# Processing Record 8 of Set 4 | dogondoutchi
# Processing Record 9 of Set 4 | ardakan
# Processing Record 10 of Set 4 | camapua
# Processing Record 11 of Set 4 | saskylakh
# Processing Record 12 of Set 4 | esso
# Processing Record 13 of Set 4 | vredendal
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | zyryanka
# Processing Record 16 of Set 4 | tupik
# Processing Record 17 of Set 4 | fortuna
# Processing Record 18 of Set 4 | ketchikan
# Processing Record 19 of Set 4 | ogembo
# Processing Record 20 of Set 4 | choix
# Processing Record 21 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 4 | katsuura
# Processing Record 23 of Set 4 | saint-pierre
# Processing Record 24 of Set 4 | aykhal
# Processing Record 25 of Set 4 | oneonta
# Processing Record 26 of Set 4 | namibe
# Processing Record 27 of Set 4 | vestmannaeyjar
# Processing Record 28 of Set 4 | neosho
# Processing Record 29 of Set 4 | omboue
# Processing Record 30 of Set 4 | dingle
# Processing Record 31 of Set 4 | hami
# Processing Record 32 of Set 4 | paracuru
# Processing Record 33 of Set 4 | lagoa
# Processing Record 34 of Set 4 | ballina
# Processing Record 35 of Set 4 | mehamn
# Processing Record 36 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 4 | shagonar
# Processing Record 38 of Set 4 | jiuquan
# Processing Record 39 of Set 4 | arraial do cabo
# Processing Record 40 of Set 4 | port elizabeth
# Processing Record 41 of Set 4 | jacqueville
# Processing Record 42 of Set 4 | prince george
# Processing Record 43 of Set 4 | tautira
# Processing Record 44 of Set 4 | salalah
# Processing Record 45 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 4 | fuyang
# Processing Record 47 of Set 4 | porto novo
# Processing Record 48 of Set 4 | visby
# Processing Record 49 of Set 4 | thompson
# Processing Record 50 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 1 of Set 5 | makakilo city
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | cartagena
# Processing Record 4 of Set 5 | aswan
# Processing Record 5 of Set 5 | reconquista
# Processing Record 6 of Set 5 | hithadhoo
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | khuzdar
# Processing Record 9 of Set 5 | pangai
# Processing Record 10 of Set 5 | broome
# Processing Record 11 of Set 5 | cockburn town
# Processing Record 12 of Set 5 | ivanovka
# Processing Record 13 of Set 5 | sinnamary
# Processing Record 14 of Set 5 | poum
# Processing Record 15 of Set 5 | ostrovnoy
# Processing Record 16 of Set 5 | bouca
# Processing Record 17 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 5 | mushie
# Processing Record 19 of Set 5 | svetlyy
# Processing Record 20 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 21 of Set 5 | nelson bay
# Processing Record 22 of Set 5 | lucea
# Processing Record 23 of Set 5 | bonthe
# Processing Record 24 of Set 5 | palafrugell
# Processing Record 25 of Set 5 | pacific grove
# Processing Record 26 of Set 5 | la macarena
# Processing Record 27 of Set 5 | gilgit
# Processing Record 28 of Set 5 | kirakira
# Processing Record 29 of Set 5 | cogoleto
# Processing Record 30 of Set 5 | tazovskiy
# Processing Record 31 of Set 5 | izberbash
# Processing Record 32 of Set 5 | karaton
# Processing Record 33 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 5 | poronaysk
# Processing Record 35 of Set 5 | guerrero negro
# Processing Record 36 of Set 5 | bengkulu
# Processing Record 37 of Set 5 | bara
# Processing Record 38 of Set 5 | cherskiy
# Processing Record 39 of Set 5 | vardo
# Processing Record 40 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 41 of Set 5 | lata
# Processing Record 42 of Set 5 | oban
# Processing Record 43 of Set 5 | richards bay
# Processing Record 44 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 5 | santa maria
# Processing Record 46 of Set 5 | puerto carreno
# Processing Record 47 of Set 5 | burns lake
# Processing Record 48 of Set 5 | casteltermini
# Processing Record 49 of Set 5 | riyadh
# Processing Record 50 of Set 5 | tuktoyaktuk
# Processing Record 1 of Set 6 | padilla
# Processing Record 2 of Set 6 | kieta
# Processing Record 3 of Set 6 | pringsewu
# Processing Record 4 of Set 6 | hearst
# Processing Record 5 of Set 6 | narsaq
# Processing Record 6 of Set 6 | mangan
# Processing Record 7 of Set 6 | sagua la grande
# Processing Record 8 of Set 6 | kerki
# City not found. Skipping...
# Processing Record 9 of Set 6 | wuhu
# Processing Record 10 of Set 6 | ayolas
# Processing Record 11 of Set 6 | labuhan
# Processing Record 12 of Set 6 | stromness
# Processing Record 13 of Set 6 | torzhok
# Processing Record 14 of Set 6 | japura
# Processing Record 15 of Set 6 | kolobrzeg
# Processing Record 16 of Set 6 | phayuha khiri
# Processing Record 17 of Set 6 | ribeira grande
# Processing Record 18 of Set 6 | taltal
# Processing Record 19 of Set 6 | ahumada
# City not found. Skipping...
# Processing Record 20 of Set 6 | sampit
# Processing Record 21 of Set 6 | hiriyur
# Processing Record 22 of Set 6 | barra patuca
# Processing Record 23 of Set 6 | urucara
# Processing Record 24 of Set 6 | grand gaube
# Processing Record 25 of Set 6 | berlevag
# Processing Record 26 of Set 6 | menzelinsk
# Processing Record 27 of Set 6 | tomatlan
# Processing Record 28 of Set 6 | vilhena
# Processing Record 29 of Set 6 | nemuro
# Processing Record 30 of Set 6 | basar
# Processing Record 31 of Set 6 | vyazma
# Processing Record 32 of Set 6 | kostenec
# City not found. Skipping...
# Processing Record 33 of Set 6 | maneromango
# Processing Record 34 of Set 6 | banda aceh
# Processing Record 35 of Set 6 | kaitangata
# Processing Record 36 of Set 6 | uberlandia
# Processing Record 37 of Set 6 | tome-acu
# City not found. Skipping...
# Processing Record 38 of Set 6 | anadyr
# Processing Record 39 of Set 6 | crotone
# Processing Record 40 of Set 6 | oranjestad
# Processing Record 41 of Set 6 | saint-louis
# Processing Record 42 of Set 6 | ilhabela
# Processing Record 43 of Set 6 | port shepstone
# Processing Record 44 of Set 6 | katihar
# Processing Record 45 of Set 6 | tynda
# Processing Record 46 of Set 6 | tuatapere
# Processing Record 47 of Set 6 | baykit
# Processing Record 48 of Set 6 | jertih
# Processing Record 49 of Set 6 | codrington
# Processing Record 50 of Set 6 | tommot
# Processing Record 1 of Set 7 | westport
# Processing Record 2 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 7 | loukhi
# Processing Record 4 of Set 7 | chaiyaphum
# Processing Record 5 of Set 7 | kropotkin
# Processing Record 6 of Set 7 | prince rupert
# Processing Record 7 of Set 7 | nospelt
# Processing Record 8 of Set 7 | thinadhoo
# Processing Record 9 of Set 7 | ferme-neuve
# Processing Record 10 of Set 7 | vestnes
# Processing Record 11 of Set 7 | bauchi
# Processing Record 12 of Set 7 | camacha
# Processing Record 13 of Set 7 | chicama
# Processing Record 14 of Set 7 | paoua
# Processing Record 15 of Set 7 | chiredzi
# Processing Record 16 of Set 7 | bilibino
# Processing Record 17 of Set 7 | mitu
# Processing Record 18 of Set 7 | jijiga
# Processing Record 19 of Set 7 | umm kaddadah
# Processing Record 20 of Set 7 | namanyere
# Processing Record 21 of Set 7 | balkhash
# Processing Record 22 of Set 7 | tateyama
# Processing Record 23 of Set 7 | emerald
# Processing Record 24 of Set 7 | canillo
# Processing Record 25 of Set 7 | saint-joseph
# Processing Record 26 of Set 7 | guinticgan
# Processing Record 27 of Set 7 | puerto penasco
# Processing Record 28 of Set 7 | lavrentiya
# Processing Record 29 of Set 7 | talnakh
# Processing Record 30 of Set 7 | barranca
# Processing Record 31 of Set 7 | los llanos de aridane
# Processing Record 32 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 7 | kyra
# Processing Record 34 of Set 7 | mirnyy
# Processing Record 35 of Set 7 | airai
# Processing Record 36 of Set 7 | chuy
# Processing Record 37 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 7 | mahajanga
# Processing Record 39 of Set 7 | eyl
# Processing Record 40 of Set 7 | zabol
# Processing Record 41 of Set 7 | lompoc
# Processing Record 42 of Set 7 | kiama
# Processing Record 43 of Set 7 | isangel
# Processing Record 44 of Set 7 | kilifi
# Processing Record 45 of Set 7 | korla
# Processing Record 46 of Set 7 | bantry
# Processing Record 47 of Set 7 | iberia
# Processing Record 48 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 49 of Set 7 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 50 of Set 7 | mocajuba
# Processing Record 1 of Set 8 | kasempa
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 8 | moussoro
# Processing Record 5 of Set 8 | bairiki
# Processing Record 6 of Set 8 | muzquiz
# City not found. Skipping...
# Processing Record 7 of Set 8 | egvekinot
# Processing Record 8 of Set 8 | margate
# Processing Record 9 of Set 8 | huittinen
# Processing Record 10 of Set 8 | puerto suarez
# Processing Record 11 of Set 8 | geraldton
# Processing Record 12 of Set 8 | havoysund
# Processing Record 13 of Set 8 | warri
# Processing Record 14 of Set 8 | okhotsk
# Processing Record 15 of Set 8 | igrim
# Processing Record 16 of Set 8 | xuddur
# Processing Record 17 of Set 8 | guajara-mirim
# City not found. Skipping...
# Processing Record 18 of Set 8 | hare bay
# Processing Record 19 of Set 8 | kilindoni
# Processing Record 20 of Set 8 | lazaro cardenas
# Processing Record 21 of Set 8 | port hardy
# Processing Record 22 of Set 8 | viedma
# Processing Record 23 of Set 8 | longyearbyen
# Processing Record 24 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 25 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 8 | ironton
# Processing Record 27 of Set 8 | coahuayana
# Processing Record 28 of Set 8 | sungaipenuh
# Processing Record 29 of Set 8 | bilma
# Processing Record 30 of Set 8 | yele
# Processing Record 31 of Set 8 | kahului
# Processing Record 32 of Set 8 | fort-shevchenko
# Processing Record 33 of Set 8 | portel
# Processing Record 34 of Set 8 | whittlesea
# Processing Record 35 of Set 8 | atocha
# Processing Record 36 of Set 8 | aleppo
# Processing Record 37 of Set 8 | suba
# Processing Record 38 of Set 8 | tucuma
# Processing Record 39 of Set 8 | oni
# Processing Record 40 of Set 8 | yerbogachen
# Processing Record 41 of Set 8 | coquimbo
# Processing Record 42 of Set 8 | marsh harbour
# Processing Record 43 of Set 8 | cabo san lucas
# Processing Record 44 of Set 8 | ganzhou
# Processing Record 45 of Set 8 | adrar
# Processing Record 46 of Set 8 | mangrol
# Processing Record 47 of Set 8 | merauke
# Processing Record 48 of Set 8 | itacare
# Processing Record 49 of Set 8 | goderich
# Processing Record 50 of Set 8 | portland
# Processing Record 1 of Set 9 | vallenar
# Processing Record 2 of Set 9 | along
# Processing Record 3 of Set 9 | novobirilyussy
# Processing Record 4 of Set 9 | acari
# Processing Record 5 of Set 9 | kohlu
# Processing Record 6 of Set 9 | kokkola
# Processing Record 7 of Set 9 | mandurah
# Processing Record 8 of Set 9 | bay roberts
# Processing Record 9 of Set 9 | aksu
# Processing Record 10 of Set 9 | lorengau
# Processing Record 11 of Set 9 | praia da vitoria
# Processing Record 12 of Set 9 | hargeysa
# Processing Record 13 of Set 9 | calabozo
# Processing Record 14 of Set 9 | bundaberg
# Processing Record 15 of Set 9 | quatre cocos
# Processing Record 16 of Set 9 | samarai
# Processing Record 17 of Set 9 | edd
# Processing Record 18 of Set 9 | phan thiet
# Processing Record 19 of Set 9 | houston
# Processing Record 20 of Set 9 | kenai
# Processing Record 21 of Set 9 | vila franca do campo
# Processing Record 22 of Set 9 | nyrob
# Processing Record 23 of Set 9 | rio gallegos
# Processing Record 24 of Set 9 | shizilu
# Processing Record 25 of Set 9 | wundanyi
# Processing Record 26 of Set 9 | kloulklubed
# Processing Record 27 of Set 9 | ilulissat
# Processing Record 28 of Set 9 | singkang
# Processing Record 29 of Set 9 | kondopoga
# Processing Record 30 of Set 9 | xining
# Processing Record 31 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 32 of Set 9 | lamar
# Processing Record 33 of Set 9 | banjar
# Processing Record 34 of Set 9 | deer lake
# Processing Record 35 of Set 9 | kungurtug
# Processing Record 36 of Set 9 | tura
# Processing Record 37 of Set 9 | tahoua
# Processing Record 38 of Set 9 | luorong
# Processing Record 39 of Set 9 | nizhniy odes
# Processing Record 40 of Set 9 | gushikawa
# Processing Record 41 of Set 9 | yenagoa
# Processing Record 42 of Set 9 | mareeba
# Processing Record 43 of Set 9 | setermoen
# Processing Record 44 of Set 9 | okahandja
# Processing Record 45 of Set 9 | ejido
# Processing Record 46 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 47 of Set 9 | harnosand
# Processing Record 48 of Set 9 | hirado
# Processing Record 49 of Set 9 | ondjiva
# Processing Record 50 of Set 9 | murray bridge
# Processing Record 1 of Set 10 | zemio
# Processing Record 2 of Set 10 | cape canaveral
# Processing Record 3 of Set 10 | sechura
# Processing Record 4 of Set 10 | masuguru
# Processing Record 5 of Set 10 | leh
# Processing Record 6 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 10 | kununurra
# Processing Record 8 of Set 10 | ixtapa
# Processing Record 9 of Set 10 | sonegaon
# Processing Record 10 of Set 10 | karamken
# City not found. Skipping...
# Processing Record 11 of Set 10 | bowling green
# Processing Record 12 of Set 10 | zhaotong
# Processing Record 13 of Set 10 | valparaiso
# Processing Record 14 of Set 10 | kautokeino
# Processing Record 15 of Set 10 | alyangula
# Processing Record 16 of Set 10 | kidal
# Processing Record 17 of Set 10 | muscat
# Processing Record 18 of Set 10 | melfi
# Processing Record 19 of Set 10 | lambarene
# Processing Record 20 of Set 10 | husavik
# Processing Record 21 of Set 10 | nizhnevartovsk
# Processing Record 22 of Set 10 | mbanza-ngungu
# Processing Record 23 of Set 10 | axim
# Processing Record 24 of Set 10 | soure
# Processing Record 25 of Set 10 | sorland
# Processing Record 26 of Set 10 | dwarka
# Processing Record 27 of Set 10 | namyslow
# Processing Record 28 of Set 10 | xichang
# Processing Record 29 of Set 10 | clyde river
# Processing Record 30 of Set 10 | marzuq
# Processing Record 31 of Set 10 | bihoro
# Processing Record 32 of Set 10 | quelimane
# Processing Record 33 of Set 10 | barinas
# Processing Record 34 of Set 10 | shingu
# Processing Record 35 of Set 10 | oranjemund
# Processing Record 36 of Set 10 | meulaboh
# Processing Record 37 of Set 10 | rovaniemi
# Processing Record 38 of Set 10 | taoudenni
# Processing Record 39 of Set 10 | sorong
# Processing Record 40 of Set 10 | berekum
# Processing Record 41 of Set 10 | vanavara
# Processing Record 42 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 43 of Set 10 | valentin gomez farias
# Processing Record 44 of Set 10 | ambon
# Processing Record 45 of Set 10 | khani
# Processing Record 46 of Set 10 | nioro
# Processing Record 47 of Set 10 | gamba
# Processing Record 48 of Set 10 | terrace
# Processing Record 49 of Set 10 | caravelas
# Processing Record 50 of Set 10 | shakawe
# Processing Record 1 of Set 11 | chimbote
# Processing Record 2 of Set 11 | te anau
# Processing Record 3 of Set 11 | smolenka
# Processing Record 4 of Set 11 | machaneng
# Processing Record 5 of Set 11 | conner
# Processing Record 6 of Set 11 | alofi
# Processing Record 7 of Set 11 | chumikan
# Processing Record 8 of Set 11 | ibotirama
# Processing Record 9 of Set 11 | adrian
# Processing Record 10 of Set 11 | miles city
# Processing Record 11 of Set 11 | cayenne
# Processing Record 12 of Set 11 | unye
# City not found. Skipping...
# Processing Record 13 of Set 11 | urumqi
# Processing Record 14 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 11 | cap malheureux
# Processing Record 16 of Set 11 | xiaoshi
# Processing Record 17 of Set 11 | beringovskiy
# Processing Record 18 of Set 11 | araguaina
# Processing Record 19 of Set 11 | guarapari
# Processing Record 20 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 11 | rundu
# Processing Record 23 of Set 11 | ambilobe
# Processing Record 24 of Set 11 | luderitz
# Processing Record 25 of Set 11 | bemidji
# Processing Record 26 of Set 11 | muyezerskiy
# Processing Record 27 of Set 11 | walvis bay
# Processing Record 28 of Set 11 | nantucket
# Processing Record 29 of Set 11 | bridlington
# Processing Record 30 of Set 11 | bartlesville
# Processing Record 31 of Set 11 | mugumu
# Processing Record 32 of Set 11 | berezovka
# Processing Record 33 of Set 11 | ravar
# Processing Record 34 of Set 11 | namatanai
# Processing Record 35 of Set 11 | makokou
# Processing Record 36 of Set 11 | kamina
# Processing Record 37 of Set 11 | aripuana
# Processing Record 38 of Set 11 | hirtshals
# Processing Record 39 of Set 11 | chara
# Processing Record 40 of Set 11 | deori
# Processing Record 41 of Set 11 | yefremov
# Processing Record 42 of Set 11 | takoradi
# Processing Record 43 of Set 11 | boone
# Processing Record 44 of Set 11 | lisala
# Processing Record 45 of Set 11 | klaksvik
# Processing Record 46 of Set 11 | ugoofaaru
# Processing Record 47 of Set 11 | bandar
# Processing Record 48 of Set 11 | san quintin
# Processing Record 49 of Set 11 | kasongo-lunda
# Processing Record 50 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 12 | general roca
# Processing Record 2 of Set 12 | omsukchan
# Processing Record 3 of Set 12 | rantepao
# Processing Record 4 of Set 12 | junin
# Processing Record 5 of Set 12 | karratha
# Processing Record 6 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 7 of Set 12 | bhag
# Processing Record 8 of Set 12 | agua verde
# Processing Record 9 of Set 12 | camana
# Processing Record 10 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 11 of Set 12 | bougouni
# Processing Record 12 of Set 12 | nishihara
# Processing Record 13 of Set 12 | praia
# Processing Record 14 of Set 12 | le port
# Processing Record 15 of Set 12 | sonoita
# Processing Record 16 of Set 12 | khuzhir
# Processing Record 17 of Set 12 | bosaso
# Processing Record 18 of Set 12 | mahebourg
# Processing Record 19 of Set 12 | ola
# Processing Record 20 of Set 12 | boa vista
# Processing Record 21 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 22 of Set 12 | manicore
# Processing Record 23 of Set 12 | irtyshskiy
# Processing Record 24 of Set 12 | galesong
# Processing Record 25 of Set 12 | isla mujeres
# Processing Record 26 of Set 12 | saint anthony
# Processing Record 27 of Set 12 | whitehorse
# Processing Record 28 of Set 12 | opuwo
# Processing Record 29 of Set 12 | vao
# Processing Record 30 of Set 12 | sindand
# City not found. Skipping...
# Processing Record 31 of Set 12 | wagar
# Processing Record 32 of Set 12 | itaobim
# Processing Record 33 of Set 12 | vanimo
# Processing Record 34 of Set 12 | ouallam
# Processing Record 35 of Set 12 | roald
# Processing Record 36 of Set 12 | shigony
# Processing Record 37 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 12 | pemangkat
# Processing Record 39 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 12 | coihaique
# Processing Record 41 of Set 12 | misratah
# Processing Record 42 of Set 12 | kargil
# Processing Record 43 of Set 12 | freetown
# Processing Record 44 of Set 12 | pak chong
# Processing Record 45 of Set 12 | dalvik
# Processing Record 46 of Set 12 | santa rosa
# Processing Record 47 of Set 12 | qaqortoq
# Processing Record 48 of Set 12 | estreito
# Processing Record 49 of Set 12 | areosa
# Processing Record 50 of Set 12 | ponta delgada
# Processing Record 1 of Set 13 | koulikoro
# Processing Record 2 of Set 13 | rehoboth
# Processing Record 3 of Set 13 | balingasay
# Processing Record 4 of Set 13 | alim
# Processing Record 5 of Set 13 | the valley
# Processing Record 6 of Set 13 | matara
# Processing Record 7 of Set 13 | luena
# Processing Record 8 of Set 13 | barreirinhas
# Processing Record 9 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 13 | palu
# Processing Record 11 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 12 of Set 13 | romny
# Processing Record 13 of Set 13 | jurado
# Processing Record 14 of Set 13 | bowen
# Processing Record 15 of Set 13 | nombre de dios
# Processing Record 16 of Set 13 | comodoro rivadavia
# Processing Record 17 of Set 13 | karakol
# Processing Record 18 of Set 13 | wencheng
# Processing Record 19 of Set 13 | belaya gora
# Processing Record 20 of Set 13 | sambava
# Processing Record 21 of Set 13 | santa cruz
# Processing Record 22 of Set 13 | waipawa
# Processing Record 23 of Set 13 | shitanjing
# Processing Record 24 of Set 13 | mayo
# Processing Record 25 of Set 13 | uusikaupunki
# Processing Record 26 of Set 13 | juneau
# Processing Record 27 of Set 13 | quesnel
# Processing Record 28 of Set 13 | mafinga
# Processing Record 29 of Set 13 | avera
# Processing Record 30 of Set 13 | rafai
# Processing Record 31 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 13 | lucapa
# Processing Record 33 of Set 13 | yanam
# Processing Record 34 of Set 13 | umm lajj
# Processing Record 35 of Set 13 | kawalu
# Processing Record 36 of Set 13 | schiffdorf
# Processing Record 37 of Set 13 | college
# Processing Record 38 of Set 13 | lekoni
# Processing Record 39 of Set 13 | luba
# Processing Record 40 of Set 13 | selenduma
# Processing Record 41 of Set 13 | savignano sul rubicone
# Processing Record 42 of Set 13 | fort nelson
# Processing Record 43 of Set 13 | arrecife
# Processing Record 44 of Set 13 | rio grande
# Processing Record 45 of Set 13 | tlahualilo
# City not found. Skipping...
# Processing Record 46 of Set 13 | sanming
# Processing Record 47 of Set 13 | tilichiki
# Processing Record 48 of Set 13 | rajgarh
# Processing Record 49 of Set 13 | bima
# Processing Record 50 of Set 13 | paita
# Processing Record 1 of Set 14 | havre-saint-pierre
# Processing Record 2 of Set 14 | tivaouane
# Processing Record 3 of Set 14 | starokostyantyniv
# Processing Record 4 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 6 of Set 14 | caborca
# Processing Record 7 of Set 14 | saiha
# Processing Record 8 of Set 14 | mragowo
# Processing Record 9 of Set 14 | plastun
# Processing Record 10 of Set 14 | half moon bay
# Processing Record 11 of Set 14 | ullapool
# Processing Record 12 of Set 14 | lagos
# Processing Record 13 of Set 14 | lethem
# Processing Record 14 of Set 14 | luganville
# Processing Record 15 of Set 14 | puerto baquerizo moreno
# Processing Record 16 of Set 14 | ko samui
# Processing Record 17 of Set 14 | chernyshevskiy
# Processing Record 18 of Set 14 | bronnoysund
# Processing Record 19 of Set 14 | nambucca heads
# Processing Record 20 of Set 14 | warwick
# Processing Record 21 of Set 14 | winnemucca
# Processing Record 22 of Set 14 | shakiso
# Processing Record 23 of Set 14 | zambezi
# Processing Record 24 of Set 14 | idlib
# Processing Record 25 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 14 | klamath falls
# Processing Record 27 of Set 14 | mantua
# Processing Record 28 of Set 14 | wana
# Processing Record 29 of Set 14 | havelock
# Processing Record 30 of Set 14 | valdivia
# Processing Record 31 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 32 of Set 14 | numaligarh
# Processing Record 33 of Set 14 | laguna de perlas
# Processing Record 34 of Set 14 | harper
# Processing Record 35 of Set 14 | mount isa
# Processing Record 36 of Set 14 | wasilla
# Processing Record 37 of Set 14 | garowe
# Processing Record 38 of Set 14 | toba
# Processing Record 39 of Set 14 | lao cai
# Processing Record 40 of Set 14 | pomezia
# Processing Record 41 of Set 14 | banda
# Processing Record 42 of Set 14 | salamanca
# Processing Record 43 of Set 14 | abu kamal
# Processing Record 44 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 14 | raudeberg
# Processing Record 46 of Set 14 | canmore
# Processing Record 47 of Set 14 | tete
# Processing Record 48 of Set 14 | kisaran
# Processing Record 49 of Set 14 | assiniboia
# Processing Record 50 of Set 14 | sestri levante
# Processing Record 1 of Set 15 | bama
# Processing Record 2 of Set 15 | port augusta
# Processing Record 3 of Set 15 | barreirinha
# Processing Record 4 of Set 15 | harrismith
# Processing Record 5 of Set 15 | port pirie
# Processing Record 6 of Set 15 | kortkeros
# Processing Record 7 of Set 15 | puma
# Processing Record 8 of Set 15 | billings
# Processing Record 9 of Set 15 | la ronge
# Processing Record 10 of Set 15 | jinchengjiang
# City not found. Skipping...
# Processing Record 11 of Set 15 | rincon
# Processing Record 12 of Set 15 | tamandare
# Processing Record 13 of Set 15 | xiongshi
# City not found. Skipping...
# Processing Record 14 of Set 15 | araouane
# Processing Record 15 of Set 15 | oxford
# Processing Record 16 of Set 15 | gornopravdinsk
# Processing Record 17 of Set 15 | langsa
# Processing Record 18 of Set 15 | nosy varika
# Processing Record 19 of Set 15 | bahir dar
# Processing Record 20 of Set 15 | conroe
# Processing Record 21 of Set 15 | ribas do rio pardo
# Processing Record 22 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 23 of Set 15 | nangong
# Processing Record 24 of Set 15 | abiramam
# Processing Record 25 of Set 15 | kadoma
# Processing Record 26 of Set 15 | deputatskiy
# Processing Record 27 of Set 15 | balad
# Processing Record 28 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 15 | novyye burasy
# Processing Record 30 of Set 15 | suarez
# Processing Record 31 of Set 15 | olkhovka
# Processing Record 32 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 34 of Set 15 | palmer
# Processing Record 35 of Set 15 | benguela
# Processing Record 36 of Set 15 | buala
# Processing Record 37 of Set 15 | north platte
# Processing Record 38 of Set 15 | kapit
# Processing Record 39 of Set 15 | chibuto
# Processing Record 40 of Set 15 | jining
# Processing Record 41 of Set 15 | wuxi
# Processing Record 42 of Set 15 | noumea
# Processing Record 43 of Set 15 | peniche
# Processing Record 44 of Set 15 | jacmel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Barrow      US  71.2906 -156.7887    -16.99        78           0
# 1   Kulhudhuffushi      MV   6.6221   73.0700     29.36        69          11
# 2       Carutapera      BR  -1.1950  -46.0200     24.67        92         100
# 3           Dikson      RU  73.5069   80.5464     -2.24        84         100
# 4  Bambous Virieux      MU -20.3428   57.7575     28.45        69          40
# 5           Albany      US  42.6001  -73.9662      7.90        86          90
# 6         At-Bashi      KG  41.1702   75.8106     12.15        46           9
# 7           Atuona      PF  -9.8000 -139.0333     26.10        75          14
# 8       Butaritari      KI   3.0707  172.7902     27.70        69         100
# 9            Sitka      US  57.0531 -135.3300      2.94        48           0
#
#    Wind Speed Current Description
# 0        8.23           clear sky
# 1        2.76          few clouds
# 2        2.89          light rain
# 3        9.46     overcast clouds
# 4        7.72    scattered clouds
# 5        1.30     overcast clouds
# 6        1.16           clear sky
# 7        6.79          few clouds
# 8        1.67     overcast clouds
# 9        2.06           clear sky

# %%
city_data_df.count()
# Out:
# City                   675
# Country                675
# Lat                    675
# Lng                    675
# Max Temp               675
# Humidity               675
# Cloudiness             675
# Wind Speed             675
# Current Description    675
# dtype: int64

# %%
city_data_df.to_csv("WeatherPy_Database.csv")
